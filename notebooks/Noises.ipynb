# %% [markdown]
# # Libraries

# %%
import sys
sys.path.append("../")

import numpy as np
import cv2

import itertools

from src.noises import add_noise

import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Add noises

# %%
# Load an image using OpenCV
image = cv2.imread('./sample.jpg')

image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# Add non-Gaussian noise
noisy_image = add_noise(image, noise_type='exponential', scale=100,sigma=150)
noisy_image = add_noise(noisy_image, noise_type='gaussian', scale=100,sigma=150)

plt.imshow(noisy_image,cmap='gray')
plt.show()

# %% [markdown]
# # 2. Noise Combination

# %% [markdown]
# <p>C(n,p) = n! / p!(n-p)!<p/>

# %%
noises = [
    "uniform",
    "exponential",
    "poisson",
    "gaussian",
    "salt_pepper"
]

p = 2
all_combos = np.array(list(itertools.combinations(noises, p)))
print(all_combos)
# Out:
# [['uniform' 'exponential']
#  ['uniform' 'poisson']
#  ['uniform' 'gaussian']
#  ['uniform' 'salt_pepper']
#  ['exponential' 'poisson']
#  ['exponential' 'gaussian']
#  ['exponential' 'salt_pepper']
#  ['poisson' 'gaussian']
#  ['poisson' 'salt_pepper']
#  ['gaussian' 'salt_pepper']]

# %%
plt.imshow(image,cmap='gray')

# %%
plt.imshow(noisy_image,cmap='gray')

# %%
# Display the original and noisy images
cv2.imshow('Original Image', image)
cv2.imshow('Noisy Image', noisy_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # 3. Gaussian blur

# %%
# Load an image using OpenCV
image = cv2.imread('./sample.jpg')

image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

fig, ax = plt.subplots(figsize=(5,5))

ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)

ax.imshow(image)

# %%
noisy_image = add_noise(image, noise_type='blur', ksize=(9,9))

fig, ax = plt.subplots(figsize=(5,5))

ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)

ax.imshow(noisy_image)

# %%
noisy_image = add_noise(image, noise_type='blur', ksize=(23,23))

fig, ax = plt.subplots(figsize=(5,5))

ax.yaxis.set_visible(False)
ax.xaxis.set_visible(False)

ax.imshow(noisy_image)
